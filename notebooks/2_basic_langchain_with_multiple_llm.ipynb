# %% [markdown]
# ### Load Dotenv

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Connect Google Gemini API

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
res = llm.invoke('Is developers unemployed for ai in short')

# %%
print(res.content)
# Out:
# The short answer is: **Not yet, and it's unlikely to happen in the short term.**
#
# Here's a more nuanced explanation:
#
# **Why developers are generally *not* unemployed due to AI in the short term:**
#
# * **AI is a Tool, Not a Replacement (Yet):** AI is primarily augmenting developer capabilities, not replacing them entirely. Developers are using AI tools to:
#     * **Write code faster:** AI code assistants like GitHub Copilot can generate boilerplate code, suggest solutions, and help with debugging.
#     * **Automate repetitive tasks:** AI can handle tasks like testing, deployment, and infrastructure management, freeing up developers for more complex work.
#     * **Improve code quality:** AI can identify bugs, security vulnerabilities, and suggest optimizations.
#     * **Understand existing codebases:** AI can help developers quickly grasp the logic of unfamiliar code.
# ...

# %% [markdown]
# ### Connect OpenAP API

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-5-nano-2025-08-07')

# %%
resOAI = llm.invoke('Sort function in c')

# %%
print(resOAI.content)
# Out:
# In C you typically sort using the standard library function qsort from <stdlib.h>. It can sort any array as long as you supply a comparator that knows how to compare two elements.
#
# Prototype
# int qsort(void *base, size_t nmemb, size_t size, int (*compar)(const void *, const void *));
#
# - base: pointer to the first element of the array
# - nmemb: number of elements in the array
# - size: size of each element (in bytes)
# - compar: function that compares two elements; it should return:
#   - negative if the first element is less than the second
#   - zero if they are equal
#   - positive if the first is greater than the second
#
# Examples
#
# 1) Sort an array of ints in ascending order
# #include <stdio.h>
# #include <stdlib.h>
#
# int cmp_ints(const void *pa, const void *pb) {
#     int a = *(const int*)pa;
#     int b = *(const int*)pb;
#     return (a > b) - (a < b);
# }
#
# int main(void) {
#     int a[] = {4, 2, 9, 1, 5};
#     size_t n = sizeof(a) / sizeof(a[0]);
# ...

# %% [markdown]
# #### Static Prompt

# %%
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
prompts = [
    ('system', 'You are a python developer'),
    ('user', 'how to sort the array')
]

# %%
resSP = llm.invoke(prompts)

# %%
print(resSP.content)
# Out:
# In Python, arrays are typically represented using lists or the `numpy` library for numerical operations. Here's how you can sort them:
#
# ---
#
# ### 1. Sorting Python Lists
#
# Python lists have built-in methods for sorting.
#
# **a) `list.sort()` method (in-place sorting):**
#
# This method sorts the list **in-place**, meaning it modifies the original list directly and returns `None`.
#
# ```python
# my_list = [3, 1, 4, 1, 5, 9, 2, 6]
# my_list.sort()
# print(my_list)  # Output: [1, 1, 2, 3, 4, 5, 6, 9]
# ```
#
# *   **Ascending Order (default):** As shown above, it sorts in ascending order by default.
# *   **Descending Order:** Use the `reverse=True` argument.
#
#     ```python
#     my_list = [3, 1, 4, 1, 5, 9, 2, 6]
#     my_list.sort(reverse=True)
#     print(my_list)  # Output: [9, 6, 5, 4, 3, 2, 1, 1]
#     ```
# *   **Sorting Custom Objects:** You can sort lists of custom objects by providing a `key` function. This function is applied to each element before comparison.
#
# ...
