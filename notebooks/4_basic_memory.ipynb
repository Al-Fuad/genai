# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-5-nano-2025-08-07')

# %%
prompts = [

    {
        'role': 'user',
        'content': 'Hello, I am S M Al Fuad Nur'
    }
]

res = llm.invoke(prompts)

# %%
print(res.content)
# Out:
# Nice to meet you, S M Al Fuad Nur! How can I help you today?
#
# If you’re not sure yet, you can tell me your goal or pick a task from these options:
# - Draft or edit emails, letters, or documents
# - Write or review code, scripts, or data notes
# - Learn about a topic quickly or get a summary
# - Plan a project, study schedule, or to-do list
# - Translate or summarize text
# - Brainstorm ideas or practice a language
#
# What would you like to do?

# %% [markdown]
# ### Manage History

# %%
history = []
while True:
    query = input('User: ')
    if query.lower() in ['exit', 'quit', 'bye']:
        print('Good Bye!!!')
        break

    history.append({'role':'user', 'content':query})
    print('User: ', query)

    res = llm.invoke(history)
    history.append({'role':'ai','content':res.content})
    print('AI: ', res.content, '\n')
# Out:
# User:  Hello, I am Nur
# AI:  Hi Nur! Nice to meet you. How can I help today?
#
# You can ask me anything, or I can help with:
# - Writing and editing (emails, essays, resumes)
# - Learning stuff (math, science, history, languages)
# - Coding or debugging
# - Planning (travel, projects, study schedules)
# - Brainstorming ideas or problems
# - Practicing a language or having a chat
#
# What would you like to do first? If you’d prefer, tell me a bit about your goal or topic.
#
# User:  who am i
# AI:  Nice to meet you, Nur. I only know you from what you’ve shared here, so I don’t have any other information about who you are.
#
# If you’d like, we can explore “who you are” together. Here are a few quick prompts to get started:
# - What are your top three values?
# - What roles do you play in life (student, friend, family member, worker, etc.), and how do you want to show up in them?
# - What are your main strengths or talents?
# - What are your interests or passions?
# - What is a current goal or dream you’re working toward?
#
# If you want, we can turn this into a brief personal bio. For example:
# “I am Nur, a [role], who loves [interests], working toward [goal], guided by [values].”
#
# Would you like to go through the prompts, or should I help you draft a short “Who I am” statement now?
#
# Good Bye!!!
