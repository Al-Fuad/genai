# %% [markdown]
# ### Langchain Model - OpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-5-nano-2025-08-07')

# %%
res = llm.invoke('who is pm of bd')

# %%
res.content
# Out:
# 'Sheikh Hasina (Sheikh Hasina Wazed) is the Prime Minister of Bangladesh. She has been in office since January 2009, leading the Awami League. If you want, I can provide more background or check for the very latest update.'

# %%
res2 = llm.invoke('who is pm of bd in 2026')

# %%
res2.content
# Out:
# 'As of my last update, the Prime Minister of Bangladesh is Sheikh Hasina. She has led the government since 2009 and continued through the 2018 and 2023 elections. The PM in 2026 would depend on the outcome of the next general election. If you want, I can look up the latest sources to confirm who is the PM in 2026.'
