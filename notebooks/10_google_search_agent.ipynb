# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model='openai/gpt-oss-20b')
search = GoogleSerperAPIWrapper()

# %%
search.run('Muhammad')
# Out:
# 'Muhammad: Prophet. Muhammad was an Arab religious, military, and political leader, and the founder of Islam. According to Islam, he was the final prophet of God who was divinely inspired to preach and confirm the monotheistic teachings of Adam, Noah, Abraham, Moses,... Muhammad Born: Makkah, Saudi Arabia. Muhammad Died: June 8, 632 AD, Madinah, Saudi Arabia. Muhammad Spouse: Maymunah bint al-Harith (m. 629 AD–632 AD), Safiyya bint Huyayy (m. 629 AD–632 AD), Umm Habiba (m. 628 AD–632 AD), and more. Muhammad Children: Fatimah bint Muhammad, Zainab bint Muhammad, Ibrahim ibn Muhammad, and more. Muhammad Place of burial: Al Masjid-e-Nabawi, Madinah, Saudi Arabia and Tomb of Muhammad. Muhammad Parents: Aminah bint Wahb and Abdullah ibn Abd al-Muttalib. Muhammad Full name: Abū al-Qāsim Muḥammad ibn ʿAbd Allāh ibn ʿAbd al-Muṭṭalib ibn Hāshim. Muhammad was an Arab religious, military, and political leader, and the founder of Islam. According to Islam, he was the final prophet of God who was ... 1. Muhammad was probably a historical figure. Muhammad was allegedly born in Mecca in AD 570 and died in Medina in AD 632. Dr. William Federer unpacks who Muhammad actually is and the dark history of Islam. Guest speakers at Calvary Chapel Chino Hills are ... Muhammad (born c. 570, Mecca, Arabia [now in Saudi Arabia]—died June 8, 632, Medina) was the founder of Islam and the proclaimer of the Qurʾān. Muhammad was born into the most powerful tribe in Mecca, the Quraish, around 570 A.D. The power of the Quraish derived from their role as successful merchants. Muhammad is the prophet of Islam and God\'s final and greatest messenger to mankind to perfect the same message preached by earlier prophets. 1. Muhammad was probably a historical figure. Muhammad was allegedly born in Mecca in AD 570 and died in Medina in AD 632. Muhammad (peace be upon him) was born during the year 570 according to the Gregorian calendar in the city of Makkah. He was an orphan as his father passed away ... In a nutshell, Prophet Muhammad (PBUH) is like the last piece of the puzzle in Islam. He\'s the "Seal of the Prophets," got the Quran from Allah, ...'

# %%
agent = create_agent(
    model=llm,
    tools=[
        search.run,
    ],
    system_prompt='You are an agent and can search for any question on google'
)

# %%
question = 'what happen in 5th aug, 2024'

# %%
res = agent.invoke({
    'messages':[
        {
            'role':'user',
            'content': question
        }
    ]
})

# %%
print(res['messages'][-1].content)
# Out:
# **August 5, 2024 – Key Events Around the World**
#
# | Region | What Happened |
# |--------|---------------|
# | **Bangladesh** | Prime Minister **Sheikh Hasina** resigned and fled the country by helicopter, citing political turmoil and security concerns. The move triggered a constitutional crisis and the appointment of an interim government. |
# | **United States** | The **Dow Jones Industrial Average** plunged about 1,034 points (≈2.6 %) to 38,703, marking the worst one‑day drop in nearly two years. The S&P 500 and Nasdaq also fell sharply amid worries over economic growth and inflation. |
# | **Middle East** | A series of **attacks on U.S. bases** in Iraq, Jordan, and Syria were reported. The incidents were part of the ongoing regional instability linked to the 2023–present Middle Eastern crisis. |
# | **Sports** | In the Paris 2024 Summer Olympics, **Cape Verde** won its first-ever Olympic medal—a bronze in men's flyweight boxing—raising the country’s profile on the international stage. |
# | **Global** | Several national holidays and observances were celebrated, including **International Traffic Light Day** and **National Oyster Day**. |
#
# **Why These Events Matter**
#
# - The **Bangladesh PM’s resignation** has significant implications for South‑Asian politics and regional security.
# - The **U.S. market crash** signals growing concerns about the U.S. economy, influencing global financial markets.
# - The **Middle Eastern attacks** underscore the fragile security situation in the region and could affect international diplomatic efforts.
# - The **Olympic medal** highlights the growing competitiveness of smaller nations in global sports.
#
# These are the most widely reported and impactful events that took place on **August 5, 2024**.
