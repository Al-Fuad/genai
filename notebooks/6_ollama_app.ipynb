# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model='codellama')

# %%
res = llm.invoke('hello, i am nur')

# %%
res.content
# Out:
# "\nHello Nur! It's nice to meet you. Is there something I can help you with or would you like to chat for a bit?"
