# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model='openai/gpt-oss-20b')

# %%
res = llm.invoke('who was muhammad')

# %%
print(res.content)
# Out:
# Muhammad (c. 570 – 632 CE) was the founder of Islam and is regarded by Muslims as the final prophet of God. Born in Mecca in the Arabian Peninsula, he received the first revelations of the Qur’an at age 40, which were later compiled into the holy book of Islam. He preached monotheism, social justice, and moral reform, and eventually unified the Arabian tribes under the banner of Islam. His life and teachings form the basis of Islamic belief, law, and practice.
